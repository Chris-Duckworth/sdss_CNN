# %% [markdown]
# # create_banner_plot
# - Creates banner plot (i.e. galaxy images with classification labels) for repo

# %%
from PIL import Image
import matplotlib.pyplot as plt
import numpy as np

# %%
data_dir = '../data/cleaned_datasets/'

x = np.load(data_dir + 'x.npy')
y = np.load(data_dir + 'y.npy')

# %%
fig, ax = plt.subplots(1, 7, figsize=(25, 3))

for a in ax.ravel():
    # generating random galaxy
    ind = np.random.randint(y.shape)
    a.imshow(np.squeeze(x[ind]))
    a.axis('off')
    label = 'Actual: $\lambda_R$ = {:1.2}'.format(y[ind][0])
    a.annotate(label, xy=(2, 9), color='w', fontsize=14)
    label = 'Prediction: $\lambda_R$ = {:1.2}'.format(y[ind][0])
    a.annotate(label, xy=(2, 75), color='w', fontsize=14)
    
fig.subplots_adjust(wspace=-0.57, hspace=0)
plt.show()
